# %%
import csv
import string
import nltk
import pprint
import pandas as pd
from time import time

"""
Part 2: 
    Objective: 
    
    Step 1: Read labeled tokens and group them by defined categories.

        Input:
            |     Token       |    Category   |
            |-----------------|---------------|
            |  B-person_name  |     Person    |
            |-----------------|---------------|
            | B-location_name |    Location   |
            |-----------------|---------------|
            |   B-film_actor  |    Person     |


    Output:
    
        Objective: This list will be used for calculating centroid for categories
        entity_categories = {
            'Person'   : { 'person_name', 'film_actor' },
            'Location' : { 'location_name' }
        }
        
        Objective: This list will be used for labeling words faster. 
        Brief    : The reason for this list is that when we're labeling
        words, in order to find label we have to 'find' it in entity_categories. With this list in hand we can
        find the category without looping through entity_categories.
        entity_category_dictionary = {
            'person_name' : 'Person',
            'location_name' : 'Location',        
        }
        
        
    Step 2: Read dataset and label words with their corresponding categories.
        
        Labeling action:
            
            Corina        |  B-politician_name     ----|  Person
	        Casanova      |  I-politician_name     ----|
	        ,             |  O
	        İsviçre       |  B-person_nationality  ----| Nationality
	        Federal       |  O
	        Şansölyesidir |  B-governmental_jurisdiction_basic_title  | PersonType
	        .             |  O

        Output:
            labeled_words = {
                'Corina Casanova': 'Person',
                'İsviçre': 'Nationality',
                'Şansölyesidir' : 'PersonType',
                ..
            }

"""
# Out:
# Time to create entity categories: 0.0115 mins

# %%
#### Helpers ####
 
# Removes token identifiers from string.
def remove_token_identifiers(raw_token):
    return raw_token.replace('B-', '').replace('I-', '')

# Checks whether token is inner.
def is_inner_token(raw_token):
    return raw_token.find('I-') != -1

# %%
#### STEP 1 ####

t = time()
my_printer = pprint.PrettyPrinter()

# Read file
df = pd.read_excel('data/labeled_categories.xlsx')

# Fallback category for the tokens does not belong to chosen categories
fallback_category = 'Thing'
# Main category list
category_list = [
    'Person', 'Location', 'Event', 'Organization', 'DateTime', 'PersonType', 'Currency', 'Nationality', 'Ethnicity'
]
# Initialize category-entity dictionary
entity_categories = {fallback_category : set({})}
entity_category_dictionary = {}

for category in category_list:
    entity_categories[category] = set({})

# Read Excel file and fill the dictionary
for row in df.index:
    token = remove_token_identifiers(df['Token'][row])
    token = token[:token.find(' =')]
    category = df['Category'][row]
    
    # Fallback category check
    if category == '' or category == 'Delete' or category == 'delete' or category == 'Thing' or category == 'thing':
        entity_categories[fallback_category].add(token)
        entity_category_dictionary[token] = fallback_category
        continue
    
    # Undefined category check
    if category not in category_list:
        continue
    
    # Valid category
    entity_categories[category].add(token)
    entity_category_dictionary[token] = category
                
print('Time to create entity categories: {} mins'.format(round((time() - t) / 60, 4)))

# %%
#print(entity_categories)
#print(entity_category_dictionary['person_name'])
# my_printer.pprint(entity_categories['Location'])
# Out:
# Person

# %%
 #### STEP 2 ####

t = time()

# Read dataset
with open("data/data_origin.DUMP", encoding="utf8") as tsv:
    
    labeled_words = {}
    counter = 0
    for line in csv.reader(tsv, dialect="excel-tab"):
        tokenized = line[1]
        sentence = line[2]
        
        all_words = nltk.word_tokenize(sentence)
        all_tokens = nltk.word_tokenize(tokenized)
        
        sentence_valid_tokens = []
        
        for x in range(len(all_words)):
            try:
                token_raw = all_tokens[x]
                
                if token_raw == 'O':
                    continue
                
                token = remove_token_identifiers(token_raw)
                    
                if token not in entity_category_dictionary:
                    continue
                
                # We skip inner tokens, they are handled with their begin tokens
                if is_inner_token(token_raw):
                    continue
                    
                # If we reach this point it means active token is a begin token.
                word = all_words[x]
                label = entity_category_dictionary[token]
                
                # Concat the next token with begin token, if it's an inner token
                next_index = x + 1
                next_raw_token = all_tokens[next_index]
                while is_inner_token(next_raw_token):
                    next_word = all_words[next_index]
                    word = word + ' ' + next_word
                    next_index += 1
                    next_raw_token = all_tokens[next_index]
                
                print(word + ' : ' + label)
            
            except IndexError:
                pass
            
        counter += 1
        if counter == 1000:
            break

print('Time to label the entities: {} mins'.format(round((time() - t) / 60, 4)))
# Out:
# Corina Casanova : Person
# İsviçre : Nationality
# Şansölyesidir : PersonType
# Casanova : Person
# İsviçre Federal Yüksek Mahkemesi : Thing
# avukat : PersonType
# Corina Casanova : Person
# federal : Organization
# Casanova : Person
# Almanca : Thing
# Fransızca : Thing
# İtalyanca : Location
# İspanyolca : Thing
# İsviçre Dışişleri Bakanlığı : Organization
# İsviçre : Organization
# federal : Organization
# İsviçre'nin : Nationality
# Gilgit Baltistan : Organization
# Pakistan : Location
# Urduca : Thing
# Gilgit : Organization
# Pakistan : Location
# Pakistan'ın : Location
# 72496 : Location
# Gilgit'dir : Organization
# Urduca : Thing
# Peştuca : Thing
# Wakhi : Thing
# Denton : Location
# Amerika Birleşik Devletleri'nde : Nationality
# Teksas : Location
# Denton : Location
# Oklahoma : Location
# Teksas : Location
# Teksas'ın : Location
# Teksas : Location
# Teksas : Location
# Apple'ın : Organization
# sunucu : PersonType
# Schiller : Person
# 2009'da : Thing
# Mac OS X v10.5 : Thing
# kullanıcı : Thing
# Mac OS : Thing
# Apple : Organization
# Intel : Organization
# PowerPC : Thing
# 2009 : Thing
# Intel : Organization
# kullanıcı lisansları : Thing
# Haziran 2009'dan : Thing
# Apple : Organization
# Mac OS X v10.5 : Thing
# kullanıcılar : Thing
# OS X : Thing
# OS X : Thing
# Apple : Organization
# PowerPC : Thing
# x86 : Thing
# bilgisayar : Organization
# 2006 : DateTime
# Intel : Organization
# Mac OS : Thing
# Lisansın : Person
# lisans : Person
# Apple : Organization
# Yazılımının : Organization
# Apple : Organization
# Apple'ın : Organization
# lisansı : Person
# ' a Mac OS : Thing
# tanıtır : Thing
# Leopard : Person
# Tek : Person
# kullanıcı lisansı : Thing
# Haziran : Thing
# 2009 : Thing
# Cisco : Location
# Teksas : Location
# Cisco'da : Location
# Mobley Hotel : Location
# John Slattery : Person
# Dominic Cooper : Person
# Lenf : Thing
# Akkan : Thing
# lenf : Thing
# lenf : Thing
# Sucre : Location
# Bolivya'nın : Location
# 2006 : DateTime
# Sucre : Location
# Bolivya'nın : Location
# La Paz'dan : Location
# Sucre : Location
# Bolivya'nın : Location
# gibi : Location
# Chuquisaca : Location
# Cumings : Thing
# Teksas : Location
# Fort Bend : Location
# Fort Bend County : Location
# Flevoland : Thing
# Hollanda'nın : Nationality
# Noordoostpolder : Location
# Hollanda'nın : Nationality
# Lelystad : Location
# Hollanda'ya : Nationality
# Flevoland : Thing
# Utrecht : Location
# Kuzey Hollanda : Thing
# birleşik : Location
# Hollanda : Nationality
# Randstad : Location
# Güney Hollanda : Location
# Randstad : Location
# Güney Hollanda : Location
# Flevoland'da : Thing
# Lelystad : Location
# Almere : Location
# Turkey : Location
# Teksas : Location
# Hall County : Location
# Turkey : Location
# El Paso : Location
# El Paso : Location
# county : Location
# El Paso : Location
# Meksika : Nationality
# El Paso : Location
# El Paso : Location
# El Paso : Location
# Meksika : Nationality
# Juarez : Person
# El Paso : Location
# Juarez : Person
# El Paso : Location
# El Paso : Location
# Meksikalıların : Location
# Teksas : Location
# El Paso'ya : Location
# El Paso : Location
# El Paso : Location
# El Paso : Location
# Passage : Location
# El Paso'nun : Location
# Meksika : Nationality
# El Paso'nin : Location
# 2001 Le Mans 24 Saat yarışı : Event
# ve : Event
# Chillicothe : Location
# Teksas : Location
# Hardeman : Location
# Hardeman County : Location
# APEC : Organization
# APEC : Organization
# Tayvan : Thing
# bakan : PersonType
# Eylül : DateTime
# Avustralya'nın : Nationality
# APEC : Organization
# Japonya'nın : Nationality
# APEC'in : Organization
# Endonezya'nın : Location
# Ekonomik : Organization
# işbirliği : Organization
# Osaka : Location
# APEC'in : Organization
# Ekonomik : Organization
# Ekonomik : Organization
# İşbirliği : Organization
# APEC'in : Organization
# Hastalığın : Thing
# öksürük : Thing
# Afyonkarahisar : Location
# Türkiye : Nationality
# Afyonkarahisar'da : Location
# Afyonkarahisar'da : Location
# Afyonkarahisar : Location
# Afyonkarahisar'da : Location
# Afyonkarahisar : Location
# Kocatepe : Person
# Afyonkarahisar'da : Location
# 2007 : DateTime
# üniversite : Thing
# Türkiye'nin : Nationality
# Kütahya'ya : Location
# Afyonkarahisar : Location
# a : Location
# İngiltere'nin : Location
# Peterborough : Location
# Peterborough United : Organization
# London Road : Location
# Rio Grande : Location
# Amerika Birleşik Devletleri'nde : Nationality
# Meksika körfezi'ne : Location
# Teksas : Location
# Amerika Birleşik Devletleri : Nationality
# Meksika : Nationality
# Rio Grande : Location
# İspanyolca : Thing
# Nehir : Location
# Alexandra Stadium : Location
# İngiltere'nin : Location
# Crewe : Thing
# Crewe : Thing
# Alexandra : Location
# 1906 : DateTime
# Oasis : Person
# Blur : Thing
# seven : Person
# II . Dünya : Event
# doğru : Location
# oyunun : PersonType
# Tanrının Direniş Ordusu : Organization
# ordusudur : Organization
# Hillsboro : Location
# Teksas : Location
# Hill : Person
# Hill County : Location
# Aybek : Location
# Afganistan'ın : Location
# Samangan : Location
# Samangan : Location
# Aybek : Location
# 2006 : DateTime
# Ralf Rudolf Möller : Person
# 12 Ocak 1959 : DateTime
# Recklinghausen : Location
# Almanya : Location
# Moeller : Person
# Almanya'nın : Location
# Recklinghausen : Location
# Almanya : Location
# Moeller : Person
# King : Person
# Viking : Organization
# Conan : Person
# Ermenistan : Location
# Roma : Location
# Trajan : Person
# Roma : Location
# Ermenistan : Location
# Roma : Location
# Ermenistan : Location
# Roma : Location
# Roma : Location
# Pers : Location
# İkinci Çekoslovak Cumhuriyeti : Location
# Çekçe/Slovakça : Thing
# 1938 : DateTime
# 1939 : Thing
# Çekoslovak : Location
# 1938'de : DateTime
# Münih : Location
# Çekoslovakya : Nationality
# Bohemya : Nationality
# Moravya : Location
# Almanyası'na : Nationality
# Almanya : Location
# 1939 : Thing
# Almanya'da : Location
# Hitler : Person
# Avusturya'nın : Nationality
# 1938 : DateTime
# ulus : Organization
# Avusturya'da : Nationality
# Başbakan : Person
# Milan : Organization
# Londra : Location
# Prag : Location
# Eylül : DateTime
# 1938'de : Thing
# başbakanı : Person
# Chamberlain : Person
# Berchtesgaden : Location
# Eylül : DateTime
# 1938'de : Thing
# Hitler : Person
# Mussolini : Person
# Chamberlain : Person
# Prag : Location
# Bohemya : Nationality
# Moravya : Location
# Polonya'ya : Nationality
# Münih : Location
# Prag : Location
# Slovakya : Location
# 1938'de : DateTime
# federal : Organization
# Slovakya'daki : Location
# Hitler : Person
# 1939 : Thing
# Almanya : Location
# 1939'da : Thing
# Hitler : Person
# Prag : Location
# Prag : Location
# Slovakya'nın : Location
# Fransa : Nationality
# 1939'da : Thing
# Bohemya : Nationality
# Moravya : Location
# I. Abdurrahman : Person
# İspanya'daki : Location
# Emirlik : PersonType
# Abdurrahman : Person
# Abdurrahman : Person
# Abdurrahman : Person
# Afrika : Location
# İspanya'ya : Location
# İspanya'da : Location
# Abdurrahman'ın : Person
# Abdurrahman : Person
# Monte Melkonyan : Person
# Karabağ Savaşı : Event
# Ermenistan : Location
# Ermeni : Thing
# Ermeni : Thing
# Kaliforniya'da : Organization
# Melkonyan : Person
# Lübnan : Nationality
# taşınmış ve Lübnan : Event
# yerleşmiş : Thing
# Avrupa'da : Location
# Melkonyan : Person
# Avrupa : Location
# Ermenistan : Location
# Karabağ Savaşı'nda : Event
# Ermeni : Thing
# Melkonyan : Person
# 1992 : DateTime
# Azerbaycan : Location
# Laçın : Location
# 12 Haziran 1993'te : DateTime
# Azerbaycan : Location
# İbad : Person
# II . : Person
# , : Location
# Abdurrahman : Person
# Endülüs : Location
# Abdurrahman : Person
# La Coubre patlaması : Event
# 4 Mart 1960 : DateTime
# La Coubre : Event
# Havana'da : DateTime
# Küba : Nationality
# Castro : Person
# III . : Person
# olarak : Location
# Abdurrahman : Person
# Endülüs : Location
# İspanya'da : Location
# arap : Thing
# Abdurrahman'ın : Person
# Tanca : Location
# Medinetü : Thing
# Blur : Person
# Seymour : Person
# 1989 : DateTime
# Londra'da : Location
# Brit : Event
# Song 2'nun : Event
# 2 : Event
# 2. : Event
# Oasis : Person
# Menard : Location
# ABD'nin : Location
# Teksas : Location
# Menard : Location
# Menard County : Location
# Köpek : Thing
# köpekgiller : Thing
# köpek : Thing
# köpek : Thing
# Köpekler : Thing
# köpek : Thing
# köpekler : Thing
# köpekleriydi : Thing
# köpeklerin : Thing
# köpek : Thing
# köpekler : Thing
# Köpeklerin : Thing
# köpekler : Thing
# Abdülaziz : Person
# 111 : Thing
# ve Pertevniyal : Person
# Abdülaziz : Person
# 1861 : DateTime
# Lubbock : Location
# Teksas : Location
# Teksas'ta : Location
# Lubbock'ın : Location
# Lubbock : Location
# Lubbock : Location
# Teksas : Location
# 1884 : DateTime
# Lubbock : Location
# federal : Organization
# Lubbock : Location
# Lubbock : Location
# Monterey : DateTime
# Lubbock : Location
# Teksas : Location
# Lights : Location
# Teksas : Location
# Lubbock : Location
# Christian : Person
# Lubbock : Location
# Lubbock'da : Location
# Lubbock : Location
# Lubbock'da : Location
# Meksika Körfezinden : Location
# Lubbock : Location
# Jake Gyllenhaal : Person
# prens : PersonType
# Gemma Arterton : Person
# Ben Kingsley : Person
# onun : Person
# Alfred Molina : Person
# Ronald Pickup : Person
# Steve Toussaint : Person
# Richard Coyle : Person
# Tus : DateTime
# Toby Kebbell : Person
# Reece Ritchie : Person
# William Foster : Person
# Appleby : Location
# Teksas : Location
# Nacogdoches : Location
# Nacogdoches County : Location
# Jeremy Leven'in : Person
# oyuncu : PersonType
# Abigail Breslin : Person
# Kendisine : Person
# Jesse : Person
# Evan Ellingson : Person
# Mobb Deep : Person
# Queens : Location
# New York : Organization
# Prodigy : Person
# Nisan : DateTime
# netbook : Thing
# Nemrut Dağı : Location
# Nemrut : Location
# Stratovolkanı : Thing
# Bitlis : Organization
# Tatvan : Location
# Anadolu'da : Location
# Nemrut : Location
# yanardağdır : Thing
# Nemrut : Location
# Nemrut : Location
# Nemrut Dağı : Location
# Abdera : Location
# İskeçe : DateTime
# deniz : Thing
# Abderalıların : Location
# Abdera : Location
# Prades : Location
# Tricky : Person
# , : Person
# Kuk : Person
# Territoire de Belfort : Thing
# Fransa'nın : Nationality
# Hugh Dowding : Person
# general : Thing
# Britanya Savaşı : Event
# Hava Kuvvetleri'ne : Person
# Dowding : Person
# Financial Times : Organization
# Londra'da : Location
# Financial Times : Organization
# New York'ta : Organization
# Financial Times : Organization
# 1945 : DateTime
# Financial : Organization
# Londra : Location
# futbolcudur : Thing
# Benbrook : Location
# Teksas : Location
# Tarrant : Location
# Tarrant County : Location
# dispepsi : Thing
# gastrit : Thing
# ülserleri : Thing
# reflü : Thing
# hidroksitMagnezyum hidroksitAlüminyum : Thing
# Joseph Wilson Swan : Person
# fizikçi : PersonType
# kimyager : PersonType
# 15 Eylül 1978 : DateTime
# Reykjavik : DateTime
# İzlandalı : Nationality
# futbolcu : Thing
# İzlandalı : Nationality
# futbola : Thing
# İzlanda'nın : Nationality
# Valur : Organization
# Valur : Organization
# Reykjavik : DateTime
# Valur : Organization
# Reykjavik'de : DateTime
# PSV Eindhoven : Organization
# veremeyince , : Organization
# Premier League'de : Organization
# Chelsea'nin : Organization
# Chelsea'ye : Organization
# Chelsea'de : Organization
# futbol : Thing
# Chelsea'de : Organization
# FC Barcelona'ya : Organization
# Stoke City'den Fulham FC'ye : Organization
# United : Organization
# Swansea : Location
# AEK Atina : Organization
# Major League Soccer : Organization
# Seattle : Thing
# Sounders : Organization
# Brugge : Thing
# Emmy : Person
# Rossum : Person
# 12 Eylül 1986 : DateTime
# oyuncu : PersonType
# İngiltere : Location
# Tarsem Singh : Person
# Lee Pace : Person
# Justine Waddell'in : Person
# 2006 : DateTime
# Marcus Wesley : Person
# Robin Smith : Person
# Emil Hostina : Person
# masal : Thing
# Afrikalı : Location
# 2006 : DateTime
# Toronto : Location
# Tasha : Person
# , : Thing
# Mayıs Stadyumu : Location
# Pyongyang : Location
# Kuzey Kore'de : Location
# Mayıs : Location
# 1989'da : DateTime
# Unix : Thing
# Unix : Thing
# Ettrich : Thing
# Tübingen : Location
# UNIX : Thing
# Ettrich : Thing
# 1998'in : DateTime
# kasım : DateTime
# GPL : Thing
# Unix : Thing
# IBM : Organization
# Shuttleworth : Person
# 2006 : DateTime
# Tasman Buzulu : Person
# buzul : Thing
# Tasman Buzulu : Person
# Mount Cook : Thing
# Tasman Buzulu : Person
# Buzulu'nun : Person
# buzul : Thing
# buzulun : Person
# Hooker : Person
# Buzulu : Person
# Müller : Person
# Buzulu : Person
# Tasman : Person
# Müller : Person
# Hooker : Person
# Tasman Buzulu'nun : Person
# yazar : PersonType
# Roald Dahl : Person
# 1981 : DateTime
# Amatuniler : Thing
# Ermenice : Thing
# Ararat : Event
# Aragatsotn : Location
# Kotayk : Location
# Amatuniler : Thing
# Rachel Sarah Bilson : Person
# 25 Ağustos 1981 : DateTime
# Yahudi : Thing
# 2003 : DateTime
# ' : DateTime
# Bilson : Person
# Rachel'ın : Person
# anne : Person
# Rachel : Person
# Rachel : Person
# Rachel Bilson : Person
# 2003 : DateTime
# Bilson'ın : Person
# Bilson : Person
# 2008 : DateTime
# New York : Organization
# Love : Person
# 2008 : DateTime
# Bilson : Person
# 2003 : DateTime
# 2007 : Location
# Adam Brody'le : Person
# Rachel Bilson : Person
# Hayden Christensen'le : Person
# birlikteliklerini : Thing
# yazar : PersonType
# Roald Dahl : Person
# 1991 : DateTime
# 1991 : DateTime
# üniversite : Thing
# 8888 Ayaklanması : Event
# Callisto : Thing
# Güneş Sistemi'ndeki : Thing
# Galileo Galilei : Thing
# Güneş Sistemi'nde : Thing
# krater : Location
# Berliner : Thing
# Berliner : Thing
# Berliner : Thing
# Avrupa : Location
# Locusta : Person
# Martinelli : DateTime
# biyolog : PersonType
# Fernando : Person
# Güneybatı Afrika : Location
# Afrika : Location
# Namibya : Location
# 1990 : Thing
# manda : Organization
# Afrika : Location
# 1884 : DateTime
# Güneybatı Afrikası : Location
# 1990 : Thing
# Namibya : Location
# manda : Organization
# Afrika : Location
# Afrika : Location
# Afrika : Location
# Gordon Willard Allport : Person
# psikolog : PersonType
# Harvard Üniversitesi'nde : Organization
# Gordon Allport : Person
# 1937 : Location
# Alman : Thing
# şansölye : PersonType
# Konrad Hermann Josef Adenauer : Person
# Ocak'ta : DateTime
# Katolik : Thing
# Konrad Adenauer : Person
# Köln'de : Thing
# Freiburg : Location
# Münih : Location
# Bonn'da : Location
# Hukuk : Thing
# Köln'de : Thing
# Savcılıkta : Thing
# Avukat : PersonType
# Köln : Thing
# 1904 : Location
# Emma Weyer : Person
# evlilikten : Thing
# Konrad : Person
# 1905 : DateTime
# Alman : Thing
# 1906'dan : DateTime
# Köln : Thing
# Köln : Thing
# Adenauer : Person
# Prusya : Thing
# ardından : Thing
# ; Konrad : Person
# Adenauer'in : Person
# Alman : Thing
# Prusya : Thing
# Köln'de : Thing
# Adenauer : Person
# Alman : Thing
# Alman : Thing
# Köln : Thing
# Hukuk : Thing
# Köln : Thing
# 1921 : DateTime
# Adenauer : Person
# Prusya : Thing
# 1922 : DateTime
# . : Thing
# Alman : Thing
# Adenauer : Person
# Şansölyeliğe : PersonType
# 1933 : DateTime
# Adenauer : Person
# Prusya : Thing
# Adenauer : Person
# Berlin'den : Location
# Şansölye : PersonType
# Adenauer : Person
# Köln : Thing
# Adenauer'in : Person
# Adenauer : Person
# Katolik : Thing
# Adenauer : Person
# istediler : Person
# Köln : Thing
# 1945 : DateTime
# Köln : Thing
# Demokrat Birliği : DateTime
# Köln : Thing
# 1946 : DateTime
# Adenauer : Person
# Adenauer : Person
# eyalet : Organization
# Berlin : Location
# Bonn'da : Location
# Jon Keeyes : Person
# ABD : Location
# Karadağlı : Nationality
# 2000 Le Mans 24 Saat yarışı : Event
# ve : Event
# Yoshikatsu Kawaguchi : Person
# futbol : Thing
# meyve : Thing
# meyve : Thing
# meyve : Thing
# meyve : Thing
# 2007 : DateTime
# Russell Crowe'un : Person
# Ford : Organization
# Christian Bale : Person
# Yuma : Thing
# Gönüllü Katil : Person
# Jonathan Swift'in : Person
# Swift'in : Person
# 1726 : DateTime
# yazarın : PersonType
# yazarını : PersonType
# Lyngby Boldklub : Organization
# 1921 : DateTime
# futbol : Thing
# Lyngby : Organization
# Lyngby Boldklub : Organization
# 1921 : DateTime
# Lyngby : Organization
# Emmanuel Bodjollé : Person
# Bodjollé : Person
# Togo : Person
# Bodjollé : Person
# Togo : Person
# Kléber Dadjo : Person
# Afrika : Location
# 1967 : DateTime
# politikacısıydı : PersonType
# Fransa : Nationality
# Togo : Person
# Dadjo : Person
# Olympio : Person
# Togo : Person
# Dadjo : Person
# 1967 : DateTime
# Gnassingbé : Person
# Eyadéma : Person
# Dadjo'yu : Person
# 1967 : DateTime
# 1999 Le Mans 24 Saat yarışı : Event
# ve : Event
# Thomas Mario Haas : Person
# tenis oyuncusu : PersonType
# Mayıs : DateTime
# Haas : Person
# 1996 : Thing
# tenise : Thing
# Avustralya Açık'ta : Event
# Sidney : Location
# Leonis : Thing
# Leonis : Thing
# Scoville : Person
# acılık : Person
# biber : Thing
# Scoville : Person
# Knebworth : Location
# İngiltere : Location
# Hertfordshire : Location
# ve : Location
# Old : Location
# ve : Location
# Knebworth : Location
# Knebworth : Location
# Fransa'daki : Nationality
# Knebworth : Location
# Victoria : Person
# Nikola : Person
# 6 Eylül 1973 : DateTime
# Zrenjanin : Location
# voleybolcu : Thing
# Voleybola : Thing
# Voleybol : Thing
# Serie : Organization
# Voleybolcu : Thing
# Vladimir : Person
# Chan'in : Person
# Jackie Chan'in : Person
# 2006 : DateTime
# Amber : Person
# Rayne : Person
# 19 Eylül 1984 : DateTime
# İtalyan : Nationality
# film oyuncusu : PersonType
# 19 Eylül 1984'te : DateTime
# Amerika Birleşik Devletleri'nin : Nationality
# Michigan : Location
# Detroit : DateTime
# İtalyan : Nationality
# Amber : Person
# Rayne : Person
# Ramiro Figueiras Amarelle : Person
# futbolcusu : Thing
# İspanya : Location
# Futbol : Thing
# futboluna : Thing
# La Liga'da : Organization
# August Thiele : Person
# II . Dünya : Event
# Avrupa : Location
# Türkiye'de : Nationality
# meyve : Thing
# Türkiye'de : Nationality
# Anadolu : Location
# sultan : Location
# Asya : Location
# Avrupa : Location
# Türkiye'de : Nationality
# Shining'in : Person
# 30 Haziran 2009 : DateTime
# 2004 İtalya Süper Kupası : Event
# Serie : Organization
# İtalya Kupası : Event
# futbol : Thing
# İtalya : Event
# 200304 : DateTime
# Serie : Organization
# Milan : Organization
# 200304 : DateTime
# İtalya Kupası : Event
# Lazio : Location
# Amerika Ulusal Bilimler Akademisi : Organization
# National Center : Organization
# Science Education : Organization
# Amerika : Organization
# Oakland : Location
# California : Location
# Stanley L. Weinberg : Person
# 1983'te : Thing
# Glenn Branch : Person
# Stadio Bruno Recchioni : Location
# İtalya'nın : Location
# Fermo : DateTime
# İtalya'nın : Location
# Calcio : Organization
# Rob Reiner'ın : Person
# 1986 : DateTime
# Stephen King'in : Person
# romanının : Thing
# Fernando José Torres Sanz : Person
# 20 Mart 1984 : DateTime
# Madrid : Location
# futbolcu : Thing
# 2012'de : DateTime
# Euro : Currency
# 2012'de : DateTime
# İspanya : Location
# takımı : Organization
# Euro : Currency
# 2008 : DateTime
# Dünya Kupası : Event
# Euro : Currency
# 2012 : DateTime
# Chelsea : Organization
# Torres : Person
# etmiştir : Person
# Torres , : Organization
# Futbolla : Thing
# futbol : Thing
# futbolla : Thing
# futbol : Thing
# takımı : Organization
# futbolcu : Thing
# Futbola : Thing
# takım : Organization
# Atlético Madrid'dir : Organization
# Madrid'in : Location
# Atlético Madrid : Organization
# 2002 : DateTime
# Barcelona : Organization
# oyun : PersonType
# maçta : Person
# 2002 : DateTime
# takımıylada : Event
# Barcelona : Organization
# Torres : Person
# Atlético Madrid : Organization
# Torres : Person
# Premier League'de : Organization
# Liverpool : Thing
# Fernando Torres : Person
# Liverpool'daki : Thing
# Toulouse : Location
# Torres : Person
# Middlesbrough : Location
# United : Organization
# torres : Person
# takımındaki : Organization
# avrupa : Location
# Torres : Person
# takımıyla : Organization
# Torres : Person
# Chelsea FC'ye : Organization
# Premier League'de : Organization
# Cristiano Ronaldo'nun : Person
# Torres : Person
# Chelsea'nin : Organization
# Torres : Person
# Liverpool : Thing
# başkan : PersonType
# Torresi : Person
# Torres : Person
# Ağustos : DateTime
# 2008'de : DateTime
# Sunderland : Location
# Liverpool'un : Thing
# 2008 : DateTime
# Torres : Person
# Liverpool : Thing
# Torres : Person
# Marsilya : Location
# Liverpool : Thing
# Eylül : DateTime
# 2008 : DateTime
# Torres : Person
# Liverpool : Thing
# Emirates : Organization
# Torres : Person
# Liverpool'da : Thing
# EURO : Currency
# 2008 : DateTime
# İspanya : Location
# takımına : Organization
# Torres : Person
# Almanya'ya : Location
# İspanya'ya : Location
# Ekim : DateTime
# 2008'de : DateTime
# Liverpool : Thing
# Vicente : Person
# Torres'in : Person
# Atlético Madrid'le : Organization
# Torres : Person
# Atlético Madrid : Organization
# Başkanı : PersonType
# Enrique : Person
# Torres : Person
# Ekim : DateTime
# 2008 : DateTime
# 2008 : DateTime
# FIFPro World : Event
# Liverpool : Thing
# Ağustos : DateTime
# 2011 : DateTime
# e : Organization
# Hull : Location
# ' : Thing
# etti : Person
# , : Location
# Torres : Person
# Premier League : Organization
# Eylül : DateTime
# 2009'da : Location
# Premier League : Organization
# oyuncusu : PersonType
# Ekim : DateTime
# 2009'da : Location
# Liverpool : Thing
# Torres : Person
# 2009'da : Location
# Liverpool : Thing
# Torres : Person
# İyi : Thing
# , : Person
# Nisan : DateTime
# Birmingham : Location
# Torres : Person
# Liverpool'un : Thing
# Avrupa : Location
# Nisan : DateTime
# Benfica : Organization
# Torres : Person
# 2009 : Location
# Premier League : Organization
# Liverpool'un : Thing
# 2009 : Location
# Liverpool FC : Organization
# Hodgson : Person
# Torres'in : Person
# tutmak : Organization
# Torres : Person
# Fernando Torres : Person
# Liverpoola : Organization
# Arsenal : Organization
# Liverpool : Thing
# Torres : Person
# Torres : Person
# Ağustos : DateTime
# Torres'in : Person
# Liverpool'da : Thing
# Torres : Person
# Ağustos : DateTime
# Ekim : DateTime
# Blackburn : Location
# ' : Thing
# galibiyet : Person
# Torres : Person
# Ocak : DateTime
# 2011'de : DateTime
# bu : Person
# gol : Thing
# 2011 : DateTime
# Chelsea'ye : Organization
# Liverpool'ae : Organization
# Liverpool : Thing
# Torres : Person
# 2011 : DateTime
# Chelsea : Organization
# takımıyla : Organization
# 2011 : DateTime
# 2012 : DateTime
# Torres : Person
# Chelsea'deki : Organization
# Swansea : Location
# Ağustos : DateTime
# 2011'de : DateTime
# Torres : Person
# Eylül : DateTime
# 2011'de : DateTime
# United : Organization
# Chelsea'nin : Organization
# Chelsea'nin : Organization
# Swansea : Location
# Torres : Person
# Torres : Person
# Ekim : DateTime
# 2011'de : DateTime
# Chelsea'nin : Organization
# Genk : Location
# takımını : Organization
# Chelsea : Organization
# Torres : Person
# Chelsea'nin : Organization
# Leicester : Thing
# Chelsea : Organization
# Mart : DateTime
# 2012 : DateTime
# Chelsea'nin : Organization
# Premier League : Organization
# Mayıs : DateTime
# 2012'de : DateTime
# Chelsea : Organization
# FC Bayern Münih : Organization
# 2011 : DateTime
# Torres : Person
# Chelsea : Organization
# Bayern : Organization
# Münih : Location
# Chelsea'nin : Organization
# Drogba : Person
# Chelsea : Organization
# Bayern : Organization
# ve : Organization
# Torres : Person
# Chelsea'nin : Organization
# Reading : Organization
# Chelsea'nin : Organization
# Chelsea'nin : Organization
# Donetsk : Thing
# Torres : Person
# Donetsk : Thing
# Andriy : Person
# Torres : Person
# Chelsea'nin : Organization
# Chelsea : Organization
# Avrupa : Location
# takım : Organization
# takım : Organization
# Juan Mata : Thing
# Torres : Person
# , : Person
# Torres : Person
# Torres'in : Person
# Drogba : Person
# Chelsea'nin : Organization
# Chelsea : Organization
# Torres : Person
# Chelsea : Organization
# Leeds : Thing
# United : Organization
# İngiltere : Location
# Torres : Person
# 2012'de : DateTime
# Chelsea : Organization
# Torres : Person
# Torres'in : Person
# Chelsea : Organization
# Norwich : Thing
# Juan Mata'nın : Thing
# Torres : Person
# Chelsea : Organization
# Avrupa : Location
# gol : Thing
# Torres : Person
# David Villa : Thing
# Portekiz : Location
# karşı : DateTime
# üst : Organization
# İspanya : Location
# Nisan : DateTime
# İtalya'ya : Location
# Euro : Currency
# takımına : Organization
# İspanya'nın : Location
# Portekiz : Location
# İspanya : Location
# Torres'in : Person
# Portekiz : Location
# ve : Location
# UEFA : Currency
# İspanya : Location
# Euro : Currency
# 2008 : DateTime
# Fernando Torres : Person
# Torres : Person
# Andrés Iniesta'ya : Thing
# Fernando Torres : Person
# İspanya : Location
# İspanya : Location
# Olalla : DateTime
# Olalla : DateTime
# Mayıs : DateTime
# 2009 : Location
# Temmuz : DateTime
# 2009'da : Location
# Kazakistan : Location
# Kazakistan : Location
# Orta Asya : Thing
# Doğu Avrupa'daki : Thing
# Kazakistan : Location
# Kazakistan : Location
# Hun : Thing
# Rusya : Location
# Türkmenistan : Location
# Özbekistan : Location
# Kırgızistan : Location
# Çin Halk Cumhuriyeti : Location
# Hazar Denizi : Location
# 1999 : DateTime
# 2010'da : DateTime
# Shinzo Koroki : Person
# futbol : Thing
# 2009 : Thing
# Titanik : Event
# filmlerinin yönetmeni : PersonType
# James Cameron : Person
# Aralık : DateTime
# 2009 : Thing
# IMAX : Thing
# filmin : Thing
# milyon : Currency
# 10 Aralık 2009'da : DateTime
# Londra : Location
# Birleşik Krallık'ta : Location
# Aralık 2009'da : DateTime
# Kanada'da : Nationality
# Kanada'da : Nationality
# ise : PersonType
# görüntü : PersonType
# 3 : Event
# 2010'da : DateTime
# Sam Worthington : Person
# Sully : Person
# 6 Ekim : Location
# Mısır'da : Location
# Stadio Brianteo : Location
# Monza : Location
# futbol : Thing
# Monza : Location
# Brianza : Location
# Stadio Pietro Fortunati : Location
# Pavia : Thing
# futbol : Thing
# Pavia : Thing
# 1973 NBA All Star Maçı : Event
# 1973 : Event
# All Star maçıdır : Event
# 1977 NBA All Star Maçı : Event
# 13 Şubat : DateTime
# 1977 : Event
# Milwaukee : Location
# All Star maçıdır : Event
# Buster : Person
# Keaton : Person
# Joseph Francis Keaton : Person
# 4 Ekim : DateTime
# 1895 : DateTime
# Kansas : Location
# . 1 Şubat : DateTime
# komedi : PersonType
# ve : PersonType
# komedyenleriydi : PersonType
# Buster : Person
# Houdini : Person
# Keaton : Person
# komedyen : PersonType
# yönetmen : PersonType
# Arbuckle'ın : Person
# yapım : Thing
# Keaton : Person
# 1932 : DateTime
# Sherlock : Thing
# oyuncu : PersonType
# ağrı : Thing
# Keaton : Person
# 1932 : DateTime
# 1935'te : DateTime
# kendisine : Person
# ödülü : Event
# 1966 : DateTime
# kanserden : Thing
# Aversa : Location
# İtalya'da : Location
# Campania : Location
# Caserta ili'ne : Location
# Napoli : Location
# İtalya'daki : Location
# Aversa : Location
# manda : Organization
# Aversa : Location
# Napoli : Location
# Napoli : Location
# Aversa : Location
# Napoli : Location
# Aversa : Location
# Aversa : Location
# Aversa : Location
# Romalılar : Location
# Roma : Location
# Drengot : Location
# Aversa : Location
# Aversa : Location
# İtalya : Location
# İtalya'ya : Location
# İtalya'yı : Location
# Aversa : Location
# Aversa'nın : Location
# İtalya : Location
# İtalyan : Nationality
# Aversa : Location
# Aversa : Location
# Richard : Person
# Roma'ya : Location
# Katolik : Thing
# İtalyanlar : Nationality
# İtalya'da : Location
# Aversa : Location
# Aversa : Location
# Napoli : Location
# Napoli : Location
# Aversa'yı : Location
# saray : Thing
# Napoli : Location
# Aversa'da : Location
# Napoli : Location
# Napoli'li : Location
# Lajos : Location
# ordu : Thing
# İtalya'ya : Location
# Aversa'da : Location
# Napolililerden : Location
# Fransa'ya : Nationality
# Aversa'da : Location
# Aversa : Location
# Napoli : Location
# Aragonlulara : Location
# Bourbon : Organization
# Karlo : Location
# Fransa'nın : Nationality
# İtalya'yı : Location
# Napoliten : Location
# Napoli'de : Location
# kilise : Location
# kilise : Location
# Aversa : Location
# Italya : Location
# Aversa'nin : Location
# manda : Organization
# İtalya'da : Location
# Aversa'da : Location
# kavak : Location
# Aversa : Location
# Aversa : Location
# alkol : Organization
# Napoli : Location
# Aversa : Location
# Napoli : Location
# Aversa'da : Location
# Aversa : Location
# Tarsuslu : Location
# Romanesk : Location
# önceki : Location
# kilise : Location
# Aversa : Location
# Prison Break : Person
# Eylül : DateTime
# 2005 : DateTime
# Matt : Person
# Olmstead : Person
# Matt Earl Beesley : Person
# Bavyera Sovyet Cumhuriyeti : Location
# Münih : Location
# Sovyet Cumhuriyeti : Location
# Bavyera : Location
# Havar Molla Muhammed : Person
# Arapça : Thing
# Haziran : DateTime
# 1981 : DateTime
# Musul : Location
# Irak : Location
# Iraklı : Location
# futbolcu : Thing
# Irak : Location
# Futbol : Thing
# Hawar : Thing
# Irak'ın : Location
# Asya : Location
# futbolculardan : Thing
# Persepolis'te : Organization
# futbolcu : Thing
# Halgurd Mulla Mohammed : Location
# Irak : Location
# Takımında : Organization
# takımı : Organization
# Mosul : Location
# futbola : Thing
# Bağdat'ın : Location
# Al Ansar : Location
# Apollon : Thing
# Al Ain FC : Organization
# Al Khor : Organization
# Kıbrıs : Location
# Cumhuriyeti : Location
# Anorthosis Famagusta FC'ye : Organization
# Werder : Organization
# Bremen : Thing
# Iraklı : Location
# futbolcu : Thing
# Anorthosis Famagusta FC'nin : Organization
# Petro Doroşenko : Person
# Kazakların : Thing
# Ukrayna'nın : Location
# Rusya'nın : Location
# Henry : Person
# yazar : PersonType
# William Sydney Porter'ın : Person
# Yazar : PersonType
# Yazar : PersonType
# Algernon Sidney Porter : Person
# Mary Jane Virginia Swaim Porter : Person
# Nisan : DateTime
# 1882 : DateTime
# Mart : DateTime
# Enontekiö Havalimanı : Location
# ENF : Location
# EFET : Location
# Enontekiön : Location
# Finlandiya'nın : Location
# Enontekiö : Location
# Enontekiö'ye : Thing
# Airlines : Organization
# havalimanından : Location
# Helsinki : Location
# Finavia : Organization
# havalimanını : Location
# Enontekiö : Thing
# Saami : Thing
# Havalimanı : Location
# Airlines : Organization
# Helsinki : Location
# İrina : Person
# Rusça : Thing
# 5 Aralık 1978 : DateTime
# Fergana/Özbekistan : DateTime
# Rus : Thing
# Rus : Thing
# Avrupa : Location
# Avrupa : Location
# Fehriye Erdal : Person
# Türkiye'yi : Nationality
# Fehriye Erdal : Person
# Yunanistan : Location
# Türkiye'de : Nationality
# 1965 : DateTime
# İngiltere : Location
# İngiltere'de : Location
# Butterfly : Organization
# 1992 : DateTime
# Film Cannes Film Festivali'nde : Organization
# oyuncu : PersonType
# oyuncu : PersonType
# ödül : Event
# Terence Stamp : Person
# Maurice Dallimore : Person
# Allyson Ames : Person
# yazar : PersonType
# John Fowles'in : Person
# Londra'da : Location
# Marianne : Thing
# John Fowles'in : Person
# Fowles'in : Person
# Stadio Tupparello : Location
# İtalya'nın : Location
# Acireale : Location
# futbol : Thing
# İtalya'nın : Location
# Acireale : Location
# Neil Young : Person
# 12 Kasım 1945 : DateTime
# Kanada : Nationality
# Vokali : Thing
# Kanada'nın : Nationality
# müzisyenlerinden : PersonType
# Buffalo Springfield : Person
# Young : Person
# Neil Young : Person
# ' : DateTime
# Young'ın : Person
# Young : Person
# 1970 : DateTime
# Do n't Let It Bring You : Person
# `` Southern : Person
# Harvest : Person
# `` , : Person
# , : Location
# And The Damage Done `` ve : Person
# Of Age : Person
# Heart of Gold : Person
# 1975 : DateTime
# Young : Person
# Cortez The Killer : Person
# 1977 : Location
# 1978 : Location
# After The Goldrush : Thing
# `` gibi : Person
# Young'ın : Person
# Rust : Person
# David Gilmour : Person
# Cobain : Person
# Young'ın : Person
# 1989 : DateTime
# Free World : Event
# 1992 : DateTime
# Harvest Moon : Event
# 1970'lerin : DateTime
# 1990 : DateTime
# 1994 : DateTime
# Greendale : Thing
# 2003 : DateTime
# 2006 : DateTime
# Irak : Location
# David : Person
# Crosby : Person
# Graham Nash : Person
# Crosby : Person
# Nash : Person
# Young : Person
# 1970 : DateTime
# Neil Young : Person
# 2007 : DateTime
# Stadio Guido Angelini : Location
# İtalya'nın : Location
# Chieti : Thing
# futbol : Thing
# İtalya'nın : Location
# Calcio Chieti : Location
# Stadio Vincenzo Presti : Location
# İtalya'nın : Location
# Gela : Location
# İtalya'nın : Location
# Gela Calcio : Location
# Prison Break : Person
# Eylül : DateTime
# 2005 : DateTime
# Michael Pavone : Person
# Brad Turner : Person
# Games : Organization
# 6 Aralık 2004'te : DateTime
# 2006 : DateTime
# Stadio Porta Elisa : Location
# Lucca : Thing
# futbol : Thing
# A.S. Lucchese Libertas : Location
# 1953 NBA All Star Maçı : Event
# 1953 : Event
# Wayne : Person
# Boston : Organization
# Star maçında : Event
# Star maçı : Event
# Allen : Person
# Stadio Vanni Sanna : Location
# İtalya'nın : Location
# Sassari : Thing
# futbol : Thing
# İtalya'nın : Location
# Sassari : Thing
# Torres 1903 : Location
# 1980 NBA All Star Maçı : Event
# 1980 : Event
# Washington : Location
# All Star maçıdır : Event
# Ab Dav : Location
# Badahşan : Organization
# R & : Person
# yapım : Thing
# Stargate : Thing
# Ne Yo'nun : Person
# In My Own Words : Event
# yapılmıştır : PersonType
# Amerika Birleşik Devletleri : Nationality
# Birleşik : Location
# Krallık : PersonType
# Lampas : Location
# Sintra : Location
# 1952 NBA All Star Maçı : Event
# 1952 : Event
# Boston : Organization
# NBA All Star maçıdır : Event
# Muharebesi : Event
# 1381 : DateTime
# Sırbistan : Location
# Sırbistan'ın : Location
# muharebe : Event
# Sırbistan : Location
# Marsel : Person
# Marsel İlhan : Person
# 11 Haziran 1987 : DateTime
# tenisçi : Thing
# Türkiye : Nationality
# ilk : Thing
# Marsel : Person
# Türkiye'de : Nationality
# Marsel : Person
# Marsel : Person
# Marsel : Person
# Avustralya : Nationality
# tenisçi : Thing
# tenisçi : Thing
# tenisçi : Thing
# Fransa : Nationality
# Tenis : Thing
# Simone : Person
# ' a : Person
# ilk : Thing
# defa : Person
# bir : Thing
# Türk : Event
# Bosna : Event
# Kazan : Location
# Kazan : Location
# Kremlin : Location
# Tony Curran : Person
# Glasgow : Organization
# İskoçya : Nationality
# 13 Aralık 1969'da : DateTime
# Tony : Person
# Tony : Person
# This life : Person
# Celtic FC : Organization
# Tony : Person
# kicker : Organization
# futbolla : Thing
# futbolcu : Thing
# kicker : Organization
# Almanach : Thing
# almanak : Thing
# Kicker : Organization
# Avrupa : Location
# Chris Norman : Person
# Smokie : Person
# vokalist : Thing
# 1986'da : DateTime
# Almanya'da : Location
# Chicago Pile 1 : Location
# Şikago : DateTime
# İvane Andronikaşvili : Person
# İvan : Person
# Rus : Thing
# Andronikaşvili : Person
# okyanus : Thing
# 2008 Voleybol Erkekler Avrupa Ligi : Event
# Ligi'ne : Event
# Avrupa : Event
# 2008 Voleybol Erkekler Avrupa Ligi'nde : Event
# Haziran : DateTime
# Temmuz : DateTime
# Bursa : DateTime
# Avrupa Ligi : Person
# AaB : Organization
# Fodbold : Organization
# Danimarka'nın : Nationality
# Aalborg : Location
# futbol : Thing
# Danimarka : Nationality
# Danimarka : Nationality
# Mickey Rourke : Person
# Dermot Mulroney'in : Person
# oyuncu : PersonType
# Eric Red'in : Person
# Geoff Murphy'nin : Person
# Dominic O'Brien : Person
# 10 Ağustos 1957 : DateTime
# Dominic : Person
# Dominic O'Brien : Person
# Mayıs : DateTime
# Sharon Stone : Person
# 10 Mart 1958 : DateTime
# oyuncusu : PersonType
# yapımcı : Thing
# manken : PersonType
# Pennsylvania : Organization
# Meadville : DateTime
# Dorothy Stone'nın : Person
# Stone : Person
# Pennsylvania : Organization
# 1992 : DateTime
# Temel İçgüdü : Event
# Türkiye'de : Nationality
# Kurtlar Vadisi'nde : Person
# 2006 Voleybol Erkekler Avrupa Ligi : Event
# Discovery : Organization
# kanat : Nationality
# Think Tank : Organization
# Seattle : Location
# Washington : Location
# Discovery : Organization
# Mustafa Ulaş Ortakaya : Person
# futbolcu : Thing
# Hidrokarbon : Thing
# Jaguar Racing : Organization
# Jaguar : Organization
# adını : Organization
# Red : Organization
# Teksas : Location
# Van Zandt : Location
# Van Zandt County : Location
# 23 Ekim 1995 : DateTime
# Hill : Person
# Phil Redmond : Person
# 1995'ten : DateTime
# 2001'den : DateTime
# İskoçya : Nationality
# Bryan Kirkwood'dur : Person
# 2011 : DateTime
# nisan : DateTime
# 2011 : DateTime
# oyuncu : PersonType
# Leah : Person
# Octavia : Person
# Minor : Person
# Octavia : Person
# Octavia : Person
# Roma : Location
# Octavia'nın : Person
# Marcus Antonius'un : Organization
# Roma'lı : Location
# Roma : Location
# Romalı : Location
# Octavia : Person
# Octavia : Person
# Gaius Octavius'un : Person
# Atia : Person
# Augustus'un : Person
# İtalya'daki : Location
# Nola : Location
# Roma : Location
# Claudius : Person
# Marcus Claudius Marcellus'un : Person
# Pompey : Location
# Octavia'nın : Person
# İtalya'yı : Location
# Octavia : Person
# Claudia Marcella : Person
# Küçük : Person
# Claudia Marcella : Person
# Marcus Claudius Marcellus : Person
# İtalya'da : Location
# Mayıs : DateTime
# Octavia : Person
# Ekim : DateTime
# Roma : Location
# Marcus Antonius : Organization
# Fulvia : Person
# Octavia : Person
# Antonius'un : Person
# Julia : Person
# Antonia : Person
# Julia : Person
# Küçük Antonia'nın : Person
# Octavia'nın : Person
# Mısır : Location
# Marcus Antonius : Organization
# Octavia : Person
# Marcus Antonius'tan : Organization
# Roma'ya : Location
# Marcus Antonius : Organization
# birlik : Organization
# Octavia'dan : Person
# Octavia : Person
# Augustus : Person
# Octavia'nın : Person
# Octavia : Person
# Augustus : Person
# Augustus : Person
# Octavia : Person
# Porticus : Location
# Octaviae : Person
# tanrıça : Thing
# Octavia : Person
# Romalı : Location
# Octavia : Person
# 2 . : Person
# , 3 : Person
# . : Person
# Dortmund Üniversitesi : Organization
# Almanya'nın : Location
# Dortmund : Organization
# üniversite : Thing
# 2006 : DateTime
# Almanya'ya : Location
# : : Location
# dir : Organization
# 2008 Cup of Russia Cup of Russia : Event
# 2008 : Event
# Acate : Location
# Sicilyaca : Location
# İtalya'nın : Location
# Sicilya bölgesinde Ragusa ili'ne : Location
# İtalyan : Nationality
# Ragusa : Thing
# Romalılar : Location
# bilgisayar : Organization
# IBM : Organization
# Livermore : Location
# Abdülhamit : Person
# Osmanlı Türkçesi : Thing
# ) ( 20 : DateTime
# Mart 1725 7 : DateTime
# padişahı : Thing
# III : Person
# ve : Person
# III : Person
# Sultan I. Abdülhamit : Person
# İstanbul : DateTime
# Sultan Abdülhamid : Person
# onun : Person
# Halil Hamit Paşa : Person
# İstanbul : DateTime
# itfaiye : PersonType
# Sultan I. Abdülhamit : Person
# İstanbul'da : DateTime
# itfaiye : PersonType
# saray : Thing
# İstanbul'da : DateTime
# Sultan I. Abdülhamit : Person
# 1768 : DateTime
# 1774 : DateTime
# 1774 : DateTime
# savaş : Event
# Rusya : Location
# Eflak : Thing
# Rusya : Location
# III : Person
# . : PersonType
# Temeşvar : Location
# Avusturya : Nationality
# Rusya : Location
# Özi : Location
# İstanbul : DateTime
# üzerine , Sultan : Person
# 7 Nisan 1789'da : DateTime
# veli : Person
# Sultan I. Abdülhamit : Person
# Özi : Location
# 1789'da : DateTime
# Sultan I. Abdülhamit : Person
# mimari : PersonType
# Seniyeperver : Person
# Sultan : Location
# Sultan : Location
# Sultan : Location
# Sultan : Location
# Şehzade Murad : Person
# Şehzade Ahmed : Person
# Şehzade Süleyman : Person
# Ingvar Kamprad : Person
# 30 Mart 1926 : DateTime
# İsveç : Location
# İKEA : Organization
# şirketini : Organization
# IKEA : Organization
# Ingvar Kamprad : Person
# İsveç'te : Location
# Ingvar : Person
# Stockholm'den : DateTime
# IKEA'yı : Organization
# IKEA : Organization
# Agunnaryd : DateTime
# IKEA : Organization
# resim : Thing
# Kamprad : Person
# IKEA'nın : Organization
# IKEA : Organization
# Ingvar Kamprad : Person
# Kamprad : Person
# 1976'dan : DateTime
# Ingvar : Person
# IKEA'daki : Organization
# Laredo : Location
# Teksas : Location
# Bad Doberan : Location
# Almanya'da : Location
# Mecklenburg Vorpommern : Location
# Amerikan : Location
# Disney Channel'da : Organization
# 28 Temmuz 2006'da : DateTime
# 30 Mart 2009 : DateTime
# Riley : Person
# Hürtgen Ormanı Muharebesi : Event
# II . Dünya Savaşı'nın Batı : Event
# , 19 Eylül : DateTime
# 1944 : DateTime
# Şubat : DateTime
# arası Hürtgen : Event
# savaş : Event
# Batı Cephesi'nde : Event
# Belçika : Nationality
# Almanya : Location
# Walter Model'in : Person
# Hürtgen : Location
# II . : Person
# , Osmanlı : Person
# Abdülhamid : Person
# Çar : Thing
# Roma : Location
# İmparatorluğu : Location
# imparatorluk : Location
# Roma : Location
# Avrupa'da : Location
# imparatorluklar : Location
# Roma : Location
# İmparatorluğu : Location
# Roma : Location
# İmparatorluğu : Location
# Rusya : Location
# aşağıdaki : Thing
# 9131018 : Location
# Sırbistan : Location
# çar : Thing
# Polonya : Nationality
# Gürcistan : Location
# Kilikya Ermeni Krallığı : Location
# 1080 : Thing
# Çukurova : Location
# 2007 Voleybol Erkekler Avrupa Ligi : Event
# Franklin : Person
# Frank : Person
# Caeti : Person
# komedyen : PersonType
# oyuncu : PersonType
# Time to label the entities: 0.0155 mins
